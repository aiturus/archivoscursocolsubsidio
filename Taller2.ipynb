# %%
# Un vendedor recibe un sueldo base más un 10% extra por comisión de sus ventas, el vendedor desea saber cuánto dinero obtendrá por concepto de comisiones por las tres
# ventas que realiza en el mes y el total que recibirá en el mes tomando en cuenta su sueldo base y comisiones.

porcentajeComision = 0.10

sueldoBase = float(input("Indique su sueldo base "))
venta1 = float(input("Indique el valor de la venta numero 1 "))
venta2 = float(input("Indique el valor de la venta numero 2 "))
venta3 = float(input("Indique el valor de la venta numero 3 "))

comision = (venta1 + venta2 + venta3) * porcentajeComision
total = sueldoBase + comision

print("EL total por comisiones es de = ${:,.0f} ".format(comision))
print("EL total a recibir es de = ${:,.0f} ".format(total))
# Out:
# Indique su sueldo base 1500000
# Indique el valor de la venta numero 1 600000
# Indique el valor de la venta numero 2 758000
# Indique el valor de la venta numero 3 630000
# EL total por comisiones es de = $198,800
# EL total a recibir es de = $1,698,800

# %%
# Una tienda ofrece un descuento del 15% sobre el total de la compra y un cliente desea saber cuánto deberá pagar finalmente por su compra.

porcentajeDescuento = 0.15

valorCompra = float(input("Indique el valor de la compra "))
valorDescuento = valorCompra * porcentajeDescuento
totalVenta = valorCompra - valorDescuento

print("EL total a pagar es de = ${:,.0f} ".format(totalVenta))
# Out:
# Indique el valor de la compra 500000
# EL total a pagar es de = $425,000

# %%
# Un maestro desea saber qué porcentaje de hombres y que porcentaje de mujeres hay en un grupo de estudiantes.

hombres = int(input("Indique el numero de hombres en el grupo "))
mujeres = int(input("Indique el numero de mujeres en el grupo "))
grupo = hombres + mujeres

porcentajeHombres = round((hombres * 100) / grupo)
porcentajeMujeres = round((mujeres * 100) / grupo)

print("\nEL porcentaje de hombres es de ", porcentajeHombres, "%")
print("EL porcentaje de mujeres es de ", porcentajeMujeres, "%")
# Out:
# Indique el numero de hombres en el grupo 45
# Indique el numero de mujeres en el grupo 35
#
# EL porcentaje de hombres es de  56 %
# EL porcentaje de mujeres es de  44 %
